# %%
import pandas as pd
import scipy.sparse as sp
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv("../Data/phrasebank_features.csv")

# %%
tfidf = TfidfVectorizer(
    ngram_range=(1, 2),
    min_df=2,
    max_df=0.95,
    sublinear_tf=True,
    max_features=50000
)

X_tfidf = tfidf.fit_transform(df['sentence'])

# %%
manual = df[
    ['word_count',
     'char_count',
     'avg_word_length',
     'digit_count']
].values

# %%
manual = df[
    ['word_count',
     'char_count',
     'avg_word_length',
     'digit_count']
].values

# %%
import joblib

joblib.dump(tfidf, "../backend/models/tfidf.pkl")
# Out:
# ['../backend/models/tfidf.pkl']
