# %%
import pandas as pd
import scipy.sparse as sp
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv("../Data/phrasebank_features.csv")

# %%
tfidf = TfidfVectorizer(
    max_features=5000,
    stop_words='english',
    ngram_range=(1,2)
)

X_tfidf = tfidf.fit_transform(df['sentence'])

# %%
manual = df[
    ['word_count',
     'char_count',
     'avg_word_length',
     'digit_count']
].values

# %%
manual = df[
    ['word_count',
     'char_count',
     'avg_word_length',
     'digit_count']
].values

# %%
import joblib

joblib.dump(tfidf, "../models/tfidf.pkl")
# Out:
# ['../models/tfidf.pkl']
